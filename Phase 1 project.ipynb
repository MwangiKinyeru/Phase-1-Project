# %% [markdown]
# # NITRAM INVESTIMENT

# %% [markdown]
# ## INTRODUCION

# %% [markdown]
# #### With a vision to soar to new heights, Nitram plans to venture into the dynamic world of aircraft acquisition and operation, targeting both commercial and private enterprises. This strategic move not only aligns with the company core values of innovation and adaptability but also opens doors to unprecedented opportunities in the global aviation market.

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## The Data

# %% [markdown]
# #### Our dataset is known as **AviationData** from the National Transportation Safety Board that includes aviation accident data from 1962 to 2023 about civil aviation accidents. Click [Dataset](https://www.kaggle.com/datasets/khsamaha/aviation-accident-database-synopses) to download

# %%
df = pd.read_csv("AviationData.csv", encoding =('ISO-8859-1' ), low_memory=False)

# %%
# we use head for data inspection to check if the data has been loaded correctly
df.head(20)
# Out:
#           Event.Id Investigation.Type Accident.Number Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080   10/24/48
# 1   20001218X45447           Accident      LAX94LA336   07/19/62
# 2   20061025X01555           Accident      NYC07LA005   08/30/74
# 3   20001218X45448           Accident      LAX96LA321   06/19/77
# 4   20041105X01764           Accident      CHI79FA064   08/02/79
# 5   20170710X52551           Accident      NYC79AA106   09/17/79
# 6   20001218X45446           Accident      CHI81LA106   08/01/81
# 7   20020909X01562           Accident      SEA82DA022   01/01/82
# 8   20020909X01561           Accident      NYC82DA015   01/01/82
# 9   20020909X01560           Accident      MIA82DA029   01/01/82
# 10  20020909X01559           Accident      FTW82DA034   01/01/82
# 11  20020909X01558           Accident      ATL82DKJ10   01/01/82
# 12  20020917X02148           Accident      FTW82FRJ07   01/02/82
# 13  20020917X02134           Accident      FTW82FRA14   01/02/82
# 14  20020917X02119           Accident      FTW82FPJ10   01/02/82
# 15  20020917X02117           Accident      FTW82FPG08   01/02/82
# 16  20020917X01962           Accident      DEN82DTM08   01/02/82
# 17  20020917X01656           Accident      ANC82FAG14   01/02/82
# 18  20020917X02481           Accident      NYC82DA016   01/02/82
# 19  20020917X02339           Accident      MIA82DA028   01/02/82
#
#             Location        Country   Latitude   Longitude Airport.Code  \
# 0    MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1     BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2      Saltville, VA  United States  36.922223  -81.878056          NaN
# 3         EUREKA, CA  United States        NaN         NaN          NaN
# 4         Canton, OH  United States        NaN         NaN          NaN
# 5         BOSTON, MA  United States  42.445277  -70.758333          NaN
# 6         COTTON, MN  United States        NaN         NaN          NaN
# 7        PULLMAN, WA  United States        NaN         NaN          NaN
# 8   EAST HANOVER, NJ  United States        NaN         NaN          N58
# 9   JACKSONVILLE, FL  United States        NaN         NaN          JAX
# 10         HOBBS, NM  United States        NaN         NaN          NaN
# 11      TUSKEGEE, AL  United States        NaN         NaN          NaN
# 12         HOMER, LA  United States        NaN         NaN          NaN
# 13        HEARNE, TX  United States        NaN         NaN          T72
# 14     CHICKASHA, OK  United States        NaN         NaN          NaN
# 15   LITTLE ROCK, AR  United States        NaN         NaN          NaN
# 16        MIDWAY, UT  United States        NaN         NaN          NaN
# 17       SKWENTA, AK  United States        NaN         NaN          NaN
# 18       GALETON, PA  United States        NaN         NaN          5G6
# 19         MIAMI, FL  United States        NaN         NaN          NaN
#
#           Airport.Name  ... Purpose.of.flight Air.carrier  \
# 0                  NaN  ...          Personal         NaN
# 1                  NaN  ...          Personal         NaN
# 2                  NaN  ...          Personal         NaN
# 3                  NaN  ...          Personal         NaN
# 4                  NaN  ...          Personal         NaN
# 5                  NaN  ...               NaN  Air Canada
# 6                  NaN  ...          Personal         NaN
# 7   BLACKBURN AG STRIP  ...          Personal         NaN
# 8              HANOVER  ...          Business         NaN
# 9    JACKSONVILLE INTL  ...          Personal         NaN
# 10                 NaN  ...          Personal         NaN
# 11            TUSKEGEE  ...          Personal         NaN
# 12                 NaN  ...          Personal         NaN
# 13    HEARNE MUNICIPAL  ...          Personal         NaN
# 14                 NaN  ...          Personal         NaN
# 15                 NaN  ...          Personal         NaN
# 16         FIELD RANCH  ...          Personal         NaN
# 17                 NaN  ...          Personal         NaN
# 18      CHERRY SPRINGS  ...          Personal         NaN
# 19                 NaN  ...          Personal         NaN
#
#    Total.Fatal.Injuries Total.Serious.Injuries Total.Minor.Injuries  \
# 0                   2.0                    0.0                  0.0
# 1                   4.0                    0.0                  0.0
# 2                   3.0                    NaN                  NaN
# 3                   2.0                    0.0                  0.0
# 4                   1.0                    2.0                  NaN
# 5                   NaN                    NaN                  1.0
# 6                   4.0                    0.0                  0.0
# 7                   0.0                    0.0                  0.0
# 8                   0.0                    0.0                  0.0
# 9                   0.0                    0.0                  3.0
# 10                  0.0                    0.0                  0.0
# 11                  0.0                    0.0                  0.0
# 12                  0.0                    0.0                  1.0
# 13                  1.0                    0.0                  0.0
# 14                  1.0                    0.0                  0.0
# 15                  2.0                    0.0                  0.0
# 16                  0.0                    0.0                  0.0
# 17                  3.0                    0.0                  0.0
# 18                  0.0                    0.0                  0.0
# 19                  0.0                    0.0                  0.0
#
#    Total.Uninjured Weather.Condition  Broad.phase.of.flight   Report.Status  \
# 0              0.0               UNK                 Cruise  Probable Cause
# 1              0.0               UNK                Unknown  Probable Cause
# 2              NaN               IMC                 Cruise  Probable Cause
# 3              0.0               IMC                 Cruise  Probable Cause
# 4              0.0               VMC               Approach  Probable Cause
# 5             44.0               VMC                  Climb  Probable Cause
# 6              0.0               IMC                Unknown  Probable Cause
# 7              2.0               VMC                Takeoff  Probable Cause
# 8              2.0               IMC                Landing  Probable Cause
# 9              0.0               IMC                 Cruise  Probable Cause
# 10             1.0               VMC               Approach  Probable Cause
# 11             1.0               VMC                Landing  Probable Cause
# 12             0.0               IMC                 Cruise  Probable Cause
# 13             0.0               IMC                Takeoff  Probable Cause
# 14             0.0               IMC                 Cruise  Probable Cause
# 15             0.0               IMC                 Cruise  Probable Cause
# 16             1.0               IMC                   Taxi  Probable Cause
# 17             0.0               VMC                Unknown  Probable Cause
# 18             1.0               VMC                   Taxi  Probable Cause
# 19             2.0               VMC                 Cruise  Probable Cause
#
#    Publication.Date
# 0               NaN
# 1        19-09-1996
# 2        26-02-2007
# 3          12/09/00
# 4        16-04-1980
# 5        19-09-2017
# 6          06/11/01
# 7          01/01/82
# 8          01/01/82
# 9          01/01/82
# 10         01/01/82
# 11         01/01/82
# 12         02/01/83
# 13         02/01/83
# 14         02/01/83
# 15         02/01/83
# 16         02/01/83
# 17         02/01/83
# 18         02/01/83
# 19         02/01/83
#
# [20 rows x 31 columns]

# %% [markdown]
# ## Performing comprehensive understanding of the dataset, which is crucial for effective data cleaning and preparation.

# %%
# checking how our data looks like
df.shape
# Out:
# (88889, 31)

# %%
# overview of the columns
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
# assessing data type, missing value count and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
#  14  Make                    88826 non-null  object
#  15  Model                   88797 non-null  object
#  16  Amateur.Built           88787 non-null  object
#  17  Number.of.Engines       82805 non-null  float64
#  18  Engine.Type             81793 non-null  object
#  19  FAR.Description         32023 non-null  object
#  20  Schedule                12582 non-null  object
#  21  Purpose.of.flight       82697 non-null  object
#  22  Air.carrier             16648 non-null  object
#  23  Total.Fatal.Injuries    77488 non-null  float64
#  24  Total.Serious.Injuries  76379 non-null  float64
#  25  Total.Minor.Injuries    76956 non-null  float64
#  26  Total.Uninjured         82977 non-null  float64
#  27  Weather.Condition       84397 non-null  object
#  28  Broad.phase.of.flight   61724 non-null  object
#  29  Report.Status           82505 non-null  object
#  30  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(26)
# memory usage: 21.0+ MB

# %% [markdown]
# ## sanity check-ups and cleaning data

# %% [markdown]
# #### First, we need to check for and remove any duplicate entries in our dataset.When removing duplicates, we use a setting called the "keep" parameter. This parameter determines which duplicate to keep i.e keep = first or keep = last. This parameters keeps the first or last occurrence of the duplicate and removes the rest. For our dataset, we will use keep = first

# %%
# first we drop the duplicates
# unfortunately our dataset has no duplicates
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88884    False
# 88885    False
# 88886    False
# 88887    False
# 88888    False
# Length: 88889, dtype: bool

# %% [markdown]
# #### In our dataset, there are certain columns that do not contribute to our business problem analysis. For example, columns like "event date" or "event ID" are irrelevant to our analysis. Additionally, some columns have a large number of missing values (over 50%), and they are not related to our key areas of focus. The best course of action is to remove these columns, as they will not negatively impact the integrity or usefulness of our data.

# %%
# Dropping unnecessary columns
df= df.drop(columns=['Event.Id', 'Event.Date', 'Airport.Code', 'Airport.Name', 'Registration.Number', 'Amateur.Built', 'FAR.Description', 'Schedule', 'Air.carrier','Weather.Condition', 'Broad.phase.of.flight', 'Report.Status', 'Publication.Date'])
df
# Out:
#       Investigation.Type Accident.Number         Location        Country  \
# 0               Accident      SEA87LA080  MOOSE CREEK, ID  United States
# 1               Accident      LAX94LA336   BRIDGEPORT, CA  United States
# 2               Accident      NYC07LA005    Saltville, VA  United States
# 3               Accident      LAX96LA321       EUREKA, CA  United States
# 4               Accident      CHI79FA064       Canton, OH  United States
# ...                  ...             ...              ...            ...
# 88884           Accident      ERA23LA093    Annapolis, MD  United States
# 88885           Accident      ERA23LA095      Hampton, NH  United States
# 88886           Accident      WPR23LA075       Payson, AZ  United States
# 88887           Accident      WPR23LA076       Morgan, UT  United States
# 88888           Accident      ERA23LA097       Athens, GA  United States
#
#         Latitude   Longitude Injury.Severity Aircraft.damage  \
# 0            NaN         NaN        Fatal(2)       Destroyed
# 1            NaN         NaN        Fatal(4)       Destroyed
# 2      36.922223  -81.878056        Fatal(3)       Destroyed
# 3            NaN         NaN        Fatal(2)       Destroyed
# 4            NaN         NaN        Fatal(1)       Destroyed
# ...          ...         ...             ...             ...
# 88884        NaN         NaN           Minor             NaN
# 88885        NaN         NaN             NaN             NaN
# 88886    341525N    1112021W       Non-Fatal     Substantial
# 88887        NaN         NaN             NaN             NaN
# 88888        NaN         NaN           Minor             NaN
#
#       Aircraft.Category                        Make      Model  \
# 0                   NaN                     Stinson      108-3
# 1                   NaN                       Piper   PA24-180
# 2                   NaN                      Cessna       172M
# 3                   NaN                    Rockwell        112
# 4                   NaN                      Cessna        501
# ...                 ...                         ...        ...
# 88884               NaN                       PIPER  PA-28-151
# 88885               NaN                    BELLANCA       7ECA
# 88886          Airplane  AMERICAN CHAMPION AIRCRAFT      8GCBC
# 88887               NaN                      CESSNA       210N
# 88888               NaN                       PIPER  PA-24-260
#
#        Number.of.Engines    Engine.Type Purpose.of.flight  \
# 0                    1.0  Reciprocating          Personal
# 1                    1.0  Reciprocating          Personal
# 2                    1.0  Reciprocating          Personal
# 3                    1.0  Reciprocating          Personal
# 4                    NaN            NaN          Personal
# ...                  ...            ...               ...
# 88884                NaN            NaN          Personal
# 88885                NaN            NaN               NaN
# 88886                1.0            NaN          Personal
# 88887                NaN            NaN          Personal
# 88888                NaN            NaN          Personal
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                       2.0                     0.0                   0.0
# 1                       4.0                     0.0                   0.0
# 2                       3.0                     NaN                   NaN
# 3                       2.0                     0.0                   0.0
# 4                       1.0                     2.0                   NaN
# ...                     ...                     ...                   ...
# 88884                   0.0                     1.0                   0.0
# 88885                   0.0                     0.0                   0.0
# 88886                   0.0                     0.0                   0.0
# 88887                   0.0                     0.0                   0.0
# 88888                   0.0                     1.0                   0.0
#
#        Total.Uninjured
# 0                  0.0
# 1                  0.0
# 2                  NaN
# 3                  0.0
# 4                  0.0
# ...                ...
# 88884              0.0
# 88885              0.0
# 88886              1.0
# 88887              0.0
# 88888              1.0
#
# [88889 rows x 18 columns]

# %% [markdown]
# ## Dealing with NAN values

# %% [markdown]
# #### NaN stands for Not a Number and is a special floating-point value used to represent missing or undefined values. NaN values can occur when performing mathematical operations on invalid values, such as dividing by zero or taking the square root of a negative number. Why get bothered with NaN values?, NaN values can cause problems when performing calculations or statistical analysis on your data. They can skew your results, produce incorrect values, or cause errors in your code. Therefore, it’s often necessary to deal with them before proceeding with your analyis. How to deal with NaN values, there are several ways that is using **dropna()** removes rows or columns with NaN values **replace()** replaces NaN values with a specified value **interpolate()** fills NaN values with interpolated values.

# %%
df.columns
# Out:
# Index(['Investigation.Type', 'Accident.Number', 'Location', 'Country',
#        'Latitude', 'Longitude', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Make', 'Model', 'Number.of.Engines',
#        'Engine.Type', 'Purpose.of.flight', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured'],
#       dtype='object')

# %%
# Before droping NAN values, lets see our dataset shape 
df.shape
# Out:
# (88889, 18)

# %%
# droping NAN values
df= df.dropna()
df
# Out:
#       Investigation.Type Accident.Number          Location        Country  \
# 50682           Accident      LAX01FA308   LYTLE CREEK, CA  United States
# 54904           Accident      FTW03FA174       Cushing, OK  United States
# 61280           Accident      CHI06GA241      COLUMBUS, OH  United States
# 61649           Accident      LAX07FA026     Yuba City, CA  United States
# 61787           Accident      NYC07FA041  Summersville, WV  United States
# ...                  ...             ...               ...            ...
# 88639           Accident      CEN23LA008          Iola, TX  United States
# 88647           Accident      ERA23LA014        Dacula, GA  United States
# 88661           Accident      CEN23LA015       Ardmore, OK  United States
# 88735           Accident      CEN23LA023       Houston, TX  United States
# 88767           Accident      CEN23LA033    Bridgeport, TX  United States
#
#         Latitude    Longitude Injury.Severity Aircraft.damage  \
# 50682  34.241389  -117.539722        Fatal(1)     Substantial
# 54904  35.935833   -96.779167        Fatal(1)       Destroyed
# 61280  40.068889   -82.968334       Non-Fatal     Substantial
# 61649  38.967778  -121.626945        Fatal(2)       Destroyed
# 61787  38.248611   -80.976111        Fatal(1)       Destroyed
# ...          ...          ...             ...             ...
# 88639    304354N     0096752W       Non-Fatal     Substantial
# 88647    034055N     0835224W       Non-Fatal     Substantial
# 88661    034849N     0097722W       Non-Fatal     Substantial
# 88735    293620N     0095959W           Minor     Substantial
# 88767    331026N     0974943W       Non-Fatal     Substantial
#
#       Aircraft.Category                           Make         Model  \
# 50682          Airplane                          Piper     PA-28-181
# 54904          Airplane                         Cessna          182H
# 61280        Helicopter  Mcdonnell Douglas Helicopters          369E
# 61649          Airplane  Aircraft Mfg & Dev. Co. (amd)  CH601XL SLSA
# 61787          Airplane                         Mooney          M20R
# ...                 ...                            ...           ...
# 88639          Airplane                         CESSNA           150
# 88647          Airplane                         CESSNA         177RG
# 88661          Airplane                          BEECH          B-60
# 88735          Airplane              STEPHEN J HOFFMAN        MS-500
# 88767          Airplane                       LUSCOMBE            8E
#
#        Number.of.Engines    Engine.Type        Purpose.of.flight  \
# 50682                1.0  Reciprocating                 Personal
# 54904                1.0  Reciprocating                Skydiving
# 61280                1.0    Turbo Shaft  Public Aircraft - Local
# 61649                1.0  Reciprocating                 Personal
# 61787                1.0  Reciprocating                 Personal
# ...                  ...            ...                      ...
# 88639                1.0  Reciprocating                 Personal
# 88647                1.0  Reciprocating                 Personal
# 88661                2.0  Reciprocating                 Personal
# 88735                1.0  Reciprocating                     ASHO
# 88767                1.0  Reciprocating                 Personal
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 50682                   1.0                     0.0                   0.0
# 54904                   1.0                     2.0                   2.0
# 61280                   0.0                     0.0                   0.0
# 61649                   2.0                     0.0                   0.0
# 61787                   1.0                     0.0                   0.0
# ...                     ...                     ...                   ...
# 88639                   0.0                     0.0                   0.0
# 88647                   0.0                     0.0                   0.0
# 88661                   0.0                     0.0                   0.0
# 88735                   0.0                     1.0                   0.0
# 88767                   0.0                     0.0                   0.0
#
#        Total.Uninjured
# 50682              0.0
# 54904              1.0
# 61280              2.0
# 61649              0.0
# 61787              0.0
# ...                ...
# 88639              1.0
# 88647              2.0
# 88661              1.0
# 88735              0.0
# 88767              2.0
#
# [16974 rows x 18 columns]

# %%
# check the shape after we drop NAN values
df.shape
# Out:
# (16974, 18)

# %% [markdown]
# #### After cleaning up our data by removing certain rows and columns, our dataset now has fewer rows and columns. This process has changed the order of how the data is indexed. To fix this, we need to reset the index so that it starts from zero again.

# %%
# data before index reset
df.head()
# Out:
#       Investigation.Type Accident.Number          Location        Country  \
# 50682           Accident      LAX01FA308   LYTLE CREEK, CA  United States
# 54904           Accident      FTW03FA174       Cushing, OK  United States
# 61280           Accident      CHI06GA241      COLUMBUS, OH  United States
# 61649           Accident      LAX07FA026     Yuba City, CA  United States
# 61787           Accident      NYC07FA041  Summersville, WV  United States
#
#         Latitude    Longitude Injury.Severity Aircraft.damage  \
# 50682  34.241389  -117.539722        Fatal(1)     Substantial
# 54904  35.935833   -96.779167        Fatal(1)       Destroyed
# 61280  40.068889   -82.968334       Non-Fatal     Substantial
# 61649  38.967778  -121.626945        Fatal(2)       Destroyed
# 61787  38.248611   -80.976111        Fatal(1)       Destroyed
#
#       Aircraft.Category                           Make         Model  \
# 50682          Airplane                          Piper     PA-28-181
# 54904          Airplane                         Cessna          182H
# 61280        Helicopter  Mcdonnell Douglas Helicopters          369E
# 61649          Airplane  Aircraft Mfg & Dev. Co. (amd)  CH601XL SLSA
# 61787          Airplane                         Mooney          M20R
#
#        Number.of.Engines    Engine.Type        Purpose.of.flight  \
# 50682                1.0  Reciprocating                 Personal
# 54904                1.0  Reciprocating                Skydiving
# 61280                1.0    Turbo Shaft  Public Aircraft - Local
# 61649                1.0  Reciprocating                 Personal
# 61787                1.0  Reciprocating                 Personal
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 50682                   1.0                     0.0                   0.0
# 54904                   1.0                     2.0                   2.0
# 61280                   0.0                     0.0                   0.0
# 61649                   2.0                     0.0                   0.0
# 61787                   1.0                     0.0                   0.0
#
#        Total.Uninjured
# 50682              0.0
# 54904              1.0
# 61280              2.0
# 61649              0.0
# 61787              0.0

# %%
# after reset
df= df.reset_index(drop=True)
df
# Out:
#       Investigation.Type Accident.Number          Location        Country  \
# 0               Accident      LAX01FA308   LYTLE CREEK, CA  United States
# 1               Accident      FTW03FA174       Cushing, OK  United States
# 2               Accident      CHI06GA241      COLUMBUS, OH  United States
# 3               Accident      LAX07FA026     Yuba City, CA  United States
# 4               Accident      NYC07FA041  Summersville, WV  United States
# ...                  ...             ...               ...            ...
# 16969           Accident      CEN23LA008          Iola, TX  United States
# 16970           Accident      ERA23LA014        Dacula, GA  United States
# 16971           Accident      CEN23LA015       Ardmore, OK  United States
# 16972           Accident      CEN23LA023       Houston, TX  United States
# 16973           Accident      CEN23LA033    Bridgeport, TX  United States
#
#         Latitude    Longitude Injury.Severity Aircraft.damage  \
# 0      34.241389  -117.539722        Fatal(1)     Substantial
# 1      35.935833   -96.779167        Fatal(1)       Destroyed
# 2      40.068889   -82.968334       Non-Fatal     Substantial
# 3      38.967778  -121.626945        Fatal(2)       Destroyed
# 4      38.248611   -80.976111        Fatal(1)       Destroyed
# ...          ...          ...             ...             ...
# 16969    304354N     0096752W       Non-Fatal     Substantial
# 16970    034055N     0835224W       Non-Fatal     Substantial
# 16971    034849N     0097722W       Non-Fatal     Substantial
# 16972    293620N     0095959W           Minor     Substantial
# 16973    331026N     0974943W       Non-Fatal     Substantial
#
#       Aircraft.Category                           Make         Model  \
# 0              Airplane                          Piper     PA-28-181
# 1              Airplane                         Cessna          182H
# 2            Helicopter  Mcdonnell Douglas Helicopters          369E
# 3              Airplane  Aircraft Mfg & Dev. Co. (amd)  CH601XL SLSA
# 4              Airplane                         Mooney          M20R
# ...                 ...                            ...           ...
# 16969          Airplane                         CESSNA           150
# 16970          Airplane                         CESSNA         177RG
# 16971          Airplane                          BEECH          B-60
# 16972          Airplane              STEPHEN J HOFFMAN        MS-500
# 16973          Airplane                       LUSCOMBE            8E
#
#        Number.of.Engines    Engine.Type        Purpose.of.flight  \
# 0                    1.0  Reciprocating                 Personal
# 1                    1.0  Reciprocating                Skydiving
# 2                    1.0    Turbo Shaft  Public Aircraft - Local
# 3                    1.0  Reciprocating                 Personal
# 4                    1.0  Reciprocating                 Personal
# ...                  ...            ...                      ...
# 16969                1.0  Reciprocating                 Personal
# 16970                1.0  Reciprocating                 Personal
# 16971                2.0  Reciprocating                 Personal
# 16972                1.0  Reciprocating                     ASHO
# 16973                1.0  Reciprocating                 Personal
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                       1.0                     0.0                   0.0
# 1                       1.0                     2.0                   2.0
# 2                       0.0                     0.0                   0.0
# 3                       2.0                     0.0                   0.0
# 4                       1.0                     0.0                   0.0
# ...                     ...                     ...                   ...
# 16969                   0.0                     0.0                   0.0
# 16970                   0.0                     0.0                   0.0
# 16971                   0.0                     0.0                   0.0
# 16972                   0.0                     1.0                   0.0
# 16973                   0.0                     0.0                   0.0
#
#        Total.Uninjured
# 0                  0.0
# 1                  1.0
# 2                  2.0
# 3                  0.0
# 4                  0.0
# ...                ...
# 16969              1.0
# 16970              2.0
# 16971              1.0
# 16972              0.0
# 16973              2.0
#
# [16974 rows x 18 columns]

# %% [markdown]
# # lets save our cleaned_dataset

# %%
df.shape
# Out:
# (16974, 18)

# %%
df.to_csv("cleaned_AviationData.csv")
